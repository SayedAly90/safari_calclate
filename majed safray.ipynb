# %%
pip install deepface
# Out:
# ...
#      ------------------------------------ 108.6/108.6 kB 571.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.3/1.3 MB 4.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 103.0/103.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.9/1.9 MB 12.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 87.2/87.2 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 85.0/85.0 kB 2.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 224.5/224.5 kB 13.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 134.6/134.6 kB 8.3 MB/s eta 0:00:00
# ...
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# ...
#      -------------------------------------- 242.4/242.4 kB 7.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.0/3.0 MB 18.9 MB/s eta 0:00:00
# ...

# %%
from deepface import DeepFace
import cv2
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\e.ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\retinaface\commons\package_utils.py:19, in validate_for_keras3()
#      18 try:
# ---> 19     import tf_keras
#      21     logger.debug(f"tf_keras is already available - {tf_keras.__version__}")
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from deepface import DeepFace
#       2 import cv2
#       3 import os
#
# File c:\Users\e.ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\deepface\DeepFace.py:20
#      18 from deepface.commons import package_utils, folder_utils
#      19 from deepface.commons.logger import Logger
# ...
